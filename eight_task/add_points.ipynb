# %% [markdown]
# ![image.png](attachment:5ffd5522-e869-4aee-9d62-3bf5464455c0.png)
#
# ![image.png](attachment:dbc01271-8b69-4c2c-b1d9-cbdcca32230f.png)

# %%
import matplotlib.pyplot as plt
import numpy as np

x_points = np.array([0.079, 0.637, 1.345, 2.095, 2.782])
y_points = np.array([-4.308, -0.739, 1.697, 4.208, 6.203])

plt.scatter(x_points, y_points, color='red', s=60, zorder=5, label="Исходные точки")
plt.legend()
plt.grid(True)
plt.show()
