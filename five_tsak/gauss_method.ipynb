# %% [markdown]
# ![image.png](attachment:85a3046d-c93a-4795-867c-4f8114d553f8.png)
# ![image.png](attachment:35eac2b9-5121-43e9-8fbe-3f871e928af5.png)

# %% [markdown]
# Запишем исходную матрицу (A|B):

# %%
from sympy import pprint, Matrix

A_B = Matrix([
    [2.979, 0.427, 0.406, 0.348, 0.341],
    [0.273, 3.951, 0.217, 0.327, 0.844],
    [0.318, 0.197, 2.875, 0.166, 0.131],
    [0.219, 0.231, 0.187, 3.276, 0.381],
])

# %% [markdown]
# Далее приводим матрицу к ступенчатому виду:

# %%
step_matrix = A_B.rref()[0]
pprint(step_matrix)
# Out:
# ⎡1  0  0  0  0.0720938560352992⎤
# ⎢                              ⎥
# ⎢0  1  0  0  0.199652955625591 ⎥
# ⎢                              ⎥
# ⎢0  0  1  0  0.0183469574816255⎥
# ⎢                              ⎥
# ⎣0  0  0  1  0.0963555347160238⎦

# %% [markdown]
# Из матрицы видно, что значения x, y, z будут равны:

# %%
answer = []
for i in range(4, step_matrix.shape[0] * step_matrix.shape[1], 5):
    answer.append(step_matrix[i])

x1, x2, x3, x4 = answer

# Выводим ответ
print(f'Методом Гаусса получены следующие значения:\nx1 = {round(x1, 3)}\nx2 = {round(x2, 3)}\nx3 = {round(x3, 3)}\nx4 = {round(x4, 3)}')
# Out:
# Методом Гаусса получены следующие значения:
# x1 = 0.072
# x2 = 0.200
# x3 = 0.018
# x4 = 0.096
